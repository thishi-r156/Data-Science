# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Data preprocessing

# %%
df = pd.read_csv("/content/weatherHistory.csv")
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 18456  2008-08-17 00:00:00.000 +0200  Partly Cloudy        rain
# 18457  2008-08-17 01:00:00.000 +0200  Partly Cloudy        rain
# 18458  2008-08-17 02:00:00.000 +0200          Clear        rain
# 18459  2008-08-17 03:00:00.000 +0200  Mostly Cloudy        rain
# 18460           2008-08-17 04:00:00.            NaN         NaN
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.sort_values(by=["Formatted Date"])
# Out:
#                      Formatted Date        Summary Precip Type  \
# 2880  2006-01-01 00:00:00.000 +0100  Partly Cloudy        rain
# 2881  2006-01-01 01:00:00.000 +0100  Mostly Cloudy        rain
# 2882  2006-01-01 02:00:00.000 +0100  Mostly Cloudy        rain
# 2883  2006-01-01 03:00:00.000 +0100       Overcast        rain
# 2884  2006-01-01 04:00:00.000 +0100  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 8059  2010-08-02 19:00:00.000 +0200          Clear        rain
# 8060  2010-08-02 20:00:00.000 +0200          Clear        rain
# 8061  2010-08-02 21:00:00.000 +0200          Clear        rain
# 8062  2010-08-02 22:00:00.000 +0200  Partly Cloudy        rain
# 8063  2010-08-02 23:00:00.000 +0200          Clear        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2880         0.577778                 -4.050000      0.89            17.1143
# ...

# %%
df.groupby(['Summary']).mean()
# Out:
#                                      Temperature (C)  \
# Summary
# Breezy                                      8.431197
# Breezy and Foggy                           -1.999206
# Breezy and Mostly Cloudy                   11.250070
# Breezy and Overcast                         7.558871
# Breezy and Partly Cloudy                   11.589062
# Clear                                      11.366104
# Dangerously Windy and Partly Cloudy         8.944444
# Dry                                        34.569444
# Dry and Partly Cloudy                      29.678283
# Foggy                                       1.853599
# Humid and Mostly Cloudy                    20.428704
# Humid and Partly Cloudy                    21.759259
# Mostly Cloudy                              13.176276
# Overcast                                    6.798995
# Partly Cloudy                              15.508663
# Windy and Foggy                             8.741667
# ...

# %%
temp_df1 = df[[ "Temperature (C)", "Humidity"]]
temp_df2 = df[["Humidity", "Visibility (km)", "Loud Cover"]]
temp_df = pd.merge(temp_df1, temp_df2)
temp_df
# Out:
#          Temperature (C)  Humidity  Visibility (km)  Loud Cover
# 0               9.472222      0.89          15.8263         0.0
# 1               9.472222      0.89          14.9569         0.0
# 2               9.472222      0.89           9.9820         0.0
# 3               9.472222      0.89           9.9015         0.0
# 4               9.472222      0.89          14.9086         0.0
# ...                  ...       ...              ...         ...
# 6674724        37.727778      0.16          10.3523         0.0
# 6674725        37.727778      0.16          10.3523         0.0
# 6674726        37.727778      0.16           9.9820         0.0
# 6674727        39.905556      0.13           9.9820         0.0
# 6674728              NaN       NaN              NaN         NaN
#
# [6674729 rows x 4 columns]

# %%
# from sklearn import preprocessing

# x = df.values #returns a numpy array
# min_max_scaler = preprocessing.MinMaxScaler()
# x_scaled = min_max_scaler.fit_transform(x)
# df = pd.DataFrame(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e3e4ceef862b> in <module>
#       3 x = df.values #returns a numpy array
#       4 min_max_scaler = preprocessing.MinMaxScaler()
# ----> 5 x_scaled = min_max_scaler.fit_transform(x)
#       6 df = pd.DataFrame(x_scaled)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     414         # Reset internal state before fitting
#     415         self._reset()
# --> 416         return self.partial_fit(X, y)
# ...

# %%
df.fillna(method='bfill')
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 18456  2008-08-17 00:00:00.000 +0200  Partly Cloudy        rain
# 18457  2008-08-17 01:00:00.000 +0200  Partly Cloudy        rain
# 18458  2008-08-17 02:00:00.000 +0200          Clear        rain
# 18459  2008-08-17 03:00:00.000 +0200  Mostly Cloudy        rain
# 18460           2008-08-17 04:00:00.            NaN         NaN
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
ord1 = OrdinalEncoder()
ord1.fit([df['Summary']])

df['Summary'] = ord1.fit_transform(df[['Summary']])
df
# Out:
#                       Formatted Date  Summary Precip Type  Temperature (C)  \
# 0      2006-04-01 00:00:00.000 +0200     14.0        rain         9.472222
# 1      2006-04-01 01:00:00.000 +0200     14.0        rain         9.355556
# 2      2006-04-01 02:00:00.000 +0200     12.0        rain         9.377778
# 3      2006-04-01 03:00:00.000 +0200     14.0        rain         8.288889
# 4      2006-04-01 04:00:00.000 +0200     12.0        rain         8.755556
# ...                              ...      ...         ...              ...
# 18456  2008-08-17 00:00:00.000 +0200     14.0        rain        15.461111
# 18457  2008-08-17 01:00:00.000 +0200     14.0        rain        14.927778
# 18458  2008-08-17 02:00:00.000 +0200      5.0        rain        13.194444
# 18459  2008-08-17 03:00:00.000 +0200     12.0        rain        15.322222
# 18460           2008-08-17 04:00:00.      NaN         NaN              NaN
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [markdown]
# Descriptive Statistics

# %%
df.describe()
# Out:
#            Summary  Temperature (C)  Apparent Temperature (C)      Humidity  \
# count  18460.00000     18460.000000              18460.000000  18460.000000
# mean      11.44247        11.831738                 10.794448      0.724785
# std        3.27794         9.431906                 10.487281      0.192096
# min        0.00000       -14.088889                -22.094444      0.130000
# 25%       12.00000         4.866667                  2.450000      0.600000
# 50%       13.00000        11.644444                 11.644444      0.770000
# 75%       14.00000        18.662500                 18.662500      0.880000
# max       18.00000        39.905556                 38.377778      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       18460.000000            18460.000000     18460.000000     18460.0
# mean           10.552023              191.896154        10.143651         0.0
# ...

# %%
print(f"Skewness: {df['Temperature (C)'].skew()}")
print(f"Kurtosis: {df['Humidity'].kurt()}")
# Out:
# Skewness: 0.1539323768712321
# Kurtosis: -0.4296699919798246

# %%
sns.heatmap(df.corr())
