# %% [markdown]
# Descriptive Statistics

# %%
df.describe()
# Out:
#             Summary  Temperature (C)  Apparent Temperature (C)      Humidity  \
# count  96453.000000     96453.000000              96453.000000  96453.000000
# mean      16.006024        11.932678                 10.855029      0.734899
# std        4.361497         9.551546                 10.696847      0.195473
# min        0.000000       -21.822222                -27.716667      0.000000
# 25%       17.000000         4.688889                  2.311111      0.600000
# 50%       18.000000        12.000000                 12.000000      0.780000
# 75%       19.000000        18.838889                 18.838889      0.890000
# max       26.000000        39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# ...

# %%
print(f"Skewness: {df['Temperature (C)'].skew()}")
print(f"Kurtosis: {df['Humidity'].kurt()}")
# Out:
# Skewness: 0.09412658235198375
# Kurtosis: -0.4621699475228258

# %%
sns.heatmap(df.corr())

# %%
df.cov()
# Out:
#                             Summary  Temperature (C)  \
# Summary                   19.022659         6.109626
# Temperature (C)            6.109626        91.232037
# Apparent Temperature (C)   6.660362       101.418283
# Humidity                  -0.096440        -1.180462
# Wind Speed (km/h)          0.128400         0.591476
# Wind Bearing (degrees)    10.673424        30.758235
# Visibility (km)            2.562273        15.730071
# Loud Cover                 0.000000         0.000000
# Pressure (millibars)      73.159825        -6.085744
#
#                           Apparent Temperature (C)  Humidity  \
# Summary                                   6.660362 -0.096440
# Temperature (C)                         101.418283 -1.180462
# Apparent Temperature (C)                114.422544 -1.259941
# Humidity                                 -1.259941  0.038210
# Wind Speed (km/h)                        -4.189439 -0.304003
# Wind Bearing (degrees)                   33.346317  0.015421
# ...
